# %%
'''
TestModel_ELV.py

This is a test script to import dummy ELV data and 
run the model.

Steps:
    1. Import the main package for the FutuRaM recovery model
    2. Create the model object
    3. Import matter objects
    4. Import process objects
    5. Import flows
    6. Import transfer coefficients
    7. Validate the model
    8. Calculate the quantities of flows in the model
    9. Visualise the model
    10. The end

Dependencies:
    futuram
'''
# Out:
# '\nTestModel_ELV.py\n\nThis is a test script to import dummy ELV data and \nrun the model.\n\nSteps:\n    1. Import the main package for the FutuRaM recovery model\n    2. Create the model object\n    3. Import matter objects\n    4. Import process objects\n    5. Import flows\n    6. Import transfer coefficients\n    7. Validate the model\n    8. Calculate the quantities of flows in the model\n    9. Visualise the model\n    10. The end\n\nDependencies:\n    futuram\n'

# %%
# (other packages are imported by the subpackages and their modules)
import futuram as f

# Get the directory of the current file
dir_path = os.path.dirname(os.path.realpath(__file__))

# Set the cwd to the directory of the current file
os.chdir(dir_path)

# toggle test mode to print out more information
TEST = True

# Set the path to the data directory
DIR_DATA = "../data/"

# %%
# Create the empty model object
model = f.classes.Model("TestModel_ELV")
# Out:
# ==================================================
# 	Created model: TestModel_ELV
# ==================================================

# %%
# Take the composition xlsx and split it into csvs for each sheet
DIR_COMPOSITIONS = f.utils.xlsx_to_csvs(f"{DIR_DATA}ELV_ICE_compositions.xlsx")

# Import the matter from the csvs
f.utils.import_matter_bulk(DIR_COMPOSITIONS, model)

# Test to see if it worked:
model.print_matter_subclasses()
# Out:
# ************************************************************
# **** Splitting ELV_ICE_compositions.xlsx into CSV files ****
# ************************************************************
#
# Files were created in ../data/ELV_ICE_compositions-split
#
# Sheets extracted:
# 		ELV_ICE-prd
# 		NEW_ICE-prd
# 		ELV_ICE_parts-prd
# 		ELV_ICE_body-cpt
# 		ELV_ICE_engtrans-cpt
# 		ELV_ICE_catconv-cpt
# 		ELV_ICE_tyres-cpt
# 		ELV_ICE_elec-cpt
# 		ELV_ICE_liquids-mat
# 		ELV_ICE_batt-cpt
# 		ELV_ICE_nfe-mat
# 		ELV_ICE_slag_nfe-mat
# 		ELV_ICE_fe-mat
# 		ELV_ICE_slag_fe-mat
# 		ALL_rubber-mat
# 		ELV_ICE_ree-mat
# 		ALL_slag_ree-mat
# 		ALL_glass-mat
# 		ELV_ICE_waste_shredder-mat
# 		ALL_plastic-mat
# 		H2SO4-cmp
# 		Pb-elm
# 		ELV_ICE_rest-mat
# 		ELV_ICE_wasteoil-mat
#
#
# ------------------------------
# 	 Importing matter to TestModel_ELV from ../data/ELV_ICE_compositions-split
# ------------------------------
# Imported Pb as elm to model TestModel_ELV
# Imported H2SO4 as cmp to model TestModel_ELV
# Imported ELV_ICE_slag_fe as mat to model TestModel_ELV
# Imported ELV_ICE_rest as mat to model TestModel_ELV
# Imported ELV_ICE_ree as mat to model TestModel_ELV
# Imported ALL_rubber as mat to model TestModel_ELV
# Imported ELV_ICE_nfe as mat to model TestModel_ELV
# Imported ALL_slag_ree as mat to model TestModel_ELV
# Imported ALL_ICE_ree as mat to model TestModel_ELV
# Imported ELV_ICE_waste_shredder as mat to model TestModel_ELV
# Imported ELV_ICE_wasteoil as mat to model TestModel_ELV
# Imported ALL_glass as mat to model TestModel_ELV
# Imported ELV_ICE_slag_nfe as mat to model TestModel_ELV
# Imported ALL_plastic as mat to model TestModel_ELV
# Imported ELV_ICE_fe as mat to model TestModel_ELV
# Imported ELV_ICE_liquids as mat to model TestModel_ELV
# Imported ELV_ICE_elec as cpt to model TestModel_ELV
# Imported ELV_ICE_catconv as cpt to model TestModel_ELV
# Imported ELV_ICE_engtrans as cpt to model TestModel_ELV
# Imported ELV_ICE_tyres as cpt to model TestModel_ELV
# Imported ELV_ICE_body as cpt to model TestModel_ELV
# Imported ELV_ICE_batt as cpt to model TestModel_ELV
# Imported ELV_ICE as prd to model TestModel_ELV
# Imported ELV_ICE_parts as prd to model TestModel_ELV
# Imported NEW_ICE as prd to model TestModel_ELV
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                    There are 25 matter objects in model "TestModel_ELV"                                                                    |
# +------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Category   | Component              | Component composition (name, mass fraction))                                                                                                         |
# +------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Products   | ELV_ICE                | ELV_ICE_body: 0.55, ELV_ICE_engtrans: 0.3, ELV_ICE_catconv: 0.05, ELV_ICE_tyres: 0.04, ELV_ICE_elec: 0.02, ELV_ICE_batt: 0.02, ELV_ICE_liquids: 0.02 |
# | Products   | ELV_ICE_parts          | ELV_ICE_body: 0.55, ELV_ICE_engtrans: 0.45                                                                                                           |
# | Products   | NEW_ICE                | ELV_ICE_body: 0.55, ELV_ICE_engtrans: 0.3, ELV_ICE_catconv: 0.05, ELV_ICE_tyres: 0.04, ELV_ICE_elec: 0.02, ELV_ICE_batt: 0.02, ELV_ICE_liquids: 0.02 |
# | Components | ELV_ICE_elec           | Cu: 0.4, Al: 0.2, Au: 0.01, Ag: 0.01, Sn: 0.03, Pb: 0.01, Ni: 0.02, Pd: 0.01, ALL_plastic: 0.31                                                      |
# | Components | ELV_ICE_catconv        | ELV_ICE_ree: 0.31, ELV_ICE_fe: 0.59, ELV_ICE_rest: 0.1                                                                                               |
# | Components | ELV_ICE_engtrans       | ELV_ICE_fe: 0.9, ELV_ICE_nfe: 0.07, ELV_ICE_rest: 0.03                                                                                               |
# | Components | ELV_ICE_tyres          | ELV_ICE_fe: 0.55, ALL_rubber: 0.15, undefined: 0.30                                                                                                  |
# | Components | ELV_ICE_body           | ELV_ICE_fe: 0.63, ELV_ICE_nfe: 0.22, ALL_glass: 0.04, ELV_ICE_rest: 0.11                                                                             |
# | Components | ELV_ICE_batt           | Pb: 0.65, H2SO4: 0.25, ALL_plastic: 0.1                                                                                                              |
# | Materials  | ELV_ICE_slag_fe        | Fe: 0.1, Ni: 0.01, Mn: 0.01, ELV_ICE_rest: 0.88                                                                                                      |
# | Materials  | ELV_ICE_rest           | ELV_ICE_rest: 1.0                                                                                                                                    |
# | Materials  | ELV_ICE_ree            | Pt: 0.05, Pd: 0.05, Rh: 0.1, Ce: 0.5, ELV_ICE_rest: 0.3                                                                                              |
# | Materials  | ALL_rubber             | ALL_rubber: 1.0                                                                                                                                      |
# | Materials  | ELV_ICE_nfe            | Al: 0.55, Cu: 0.15, Pb: 0.03, Zn: 0.03, Ni: 0.02, Mg: 0.02, Sn: 0.02, ELV_ICE_rest: 0.18                                                             |
# | Materials  | ALL_slag_ree           | ELV_ICE_ree: 0.31, ELV_ICE_fe: 0.59, ELV_ICE_rest: 0.1                                                                                               |
# | Materials  | ALL_ICE_ree            | Pt: 0.05, Pd: 0.05, Rh: 0.1, Ce: 0.5, ELV_ICE_rest: 0.3                                                                                              |
# | Materials  | ELV_ICE_waste_shredder | ALL_plastic: 0.6, ELV_ICE_fe: 0.2, ELV_ICE_nfe: 0.2                                                                                                  |
# | Materials  | ELV_ICE_wasteoil       | ELV_ICE_wasteoil: 1.0                                                                                                                                |
# | Materials  | ALL_glass              | ALL_glass: 1.0                                                                                                                                       |
# | Materials  | ELV_ICE_slag_nfe       | Al: 0.1, Cu: 0.02, Pb: 0.01, Zn: 0.01, Ni: 0.01, Mg: 0.01, Sn: 0.01, ELV_ICE_rest: 0.83                                                              |
# | Materials  | ALL_plastic            | ALL_plastic: 1.0                                                                                                                                     |
# | Materials  | ELV_ICE_fe             | Fe: 0.95, Ni: 0.01, Mn: 0.01, ELV_ICE_rest: 0.03                                                                                                     |
# | Materials  | ELV_ICE_liquids        | ALL_waste_oil: 1.0                                                                                                                                   |
# | Compounds  | H2SO4                  | N/A                                                                                                                                                  |
# | Elements   | Pb                     | N/A                                                                                                                                                  |
# +------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# Add processes from the xlsx file to the model
PROCESS_XLSX = DIR_DATA + "ELV_ICE_processes.xlsx"
f.utils.import_processes_xlsx(PROCESS_XLSX, model)

## TEST
if TEST:
    print("\n\n A random process:")
    model.random_process().print_table()
    print("\n\n All processes in the model:")
    model.print_processes()
    # Inspect a random process
# Out:
# ------------------------------------------------------------
#    Importing processes to model "TestModel_ELV" from ../data/ELV_ICE_processes.xlsx
# ------------------------------------------------------------
#
# ** Importing 23 processes **
#
# 	collection_ICE
# 	dismantling_ICE
# 	market_reuse_ELVcomponents
# 	shredding_engtrans
# 	hammermill_body
# 	smelter_cc
# 	shredding_tyre
# 	shredding_elec
# 	shredding_batt
# 	smelter_nonferrous
# 	smelter_ferrous
# 	market_waste_rubber
# 	market_ree
# 	market_lead
# 	market_H2SO4
# 	market_nonferrous
# 	market_ferrous
# 	market_waste
# 	market_waste_glass
# 	market_waste_plastic
# 	market_waste_slag
# 	market_waste_oil
# 	PutOnMarket_ICE
#
#
#  A random process:
#
# ------------------------------------------------------------
# 	  Details of process: market_ree
# ------------------------------------------------------------
#
# ╒═══════════════════════╤══════════════════════════╕
# │ Attribute             │ Value                    │
# ╞═══════════════════════╪══════════════════════════╡
# │ name                  │ market_ree               │
# ├───────────────────────┼──────────────────────────┤
# │ description           │ market for waste REE mix │
# ├───────────────────────┼──────────────────────────┤
# │ WS                    │ None                     │
# ├───────────────────────┼──────────────────────────┤
# │ transformation_level  │ market                   │
# ├───────────────────────┼──────────────────────────┤
# │ tags                  │ market                   │
# ├───────────────────────┼──────────────────────────┤
# │ inputs                │ []                       │
# ├───────────────────────┼──────────────────────────┤
# │ outputs               │ []                       │
# ├───────────────────────┼──────────────────────────┤
# │ parameters            │ {}                       │
# ├───────────────────────┼──────────────────────────┤
# │ consumption_energy    │ None                     │
# ├───────────────────────┼──────────────────────────┤
# │ consumption_water     │ None                     │
# ├───────────────────────┼──────────────────────────┤
# │ cost_operation        │ -2000                    │
# ├───────────────────────┼──────────────────────────┤
# │ cost_capital          │                          │
# ├───────────────────────┼──────────────────────────┤
# │ transfer_coefficients │ []                       │
# ╘═══════════════════════╧══════════════════════════╛
#
#
#  All processes in the model:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                     Processes in "TestModel_ELV"                                                                                                                    |
# +----------------------------+----------------------------------------------------+------+----------------------+--------------------+--------+---------+------------+--------------------+-------------------+----------------+--------------+-----------------------+
# | name                       | description                                        | WS   | transformation_level | tags               | inputs | outputs | parameters | consumption_energy | consumption_water | cost_operation | cost_capital | transfer_coefficients |
# +----------------------------+----------------------------------------------------+------+----------------------+--------------------+--------+---------+------------+--------------------+-------------------+----------------+--------------+-----------------------+
# | collection_ICE             | collection of an ice car                           | ELV  | market               | collection         | []     | []      | {}         | 1                  | 1                 | 0.1            | None         | []                    |
# | dismantling_ICE            | manual dismantling of an ice car                   | ELV  | component            | manual, mechanical | []     | []      | {}         | 4                  | 2                 | 0.8            | None         | []                    |
# | market_reuse_ELVcomponents | direct or indirect reuse of components from an elv | ELV  | component            | None               | []     | []      | {}         | None               | None              | 20             | None         | []                    |
# | shredding_engtrans         | shredding of car engine and transmission           | ELV  | material             | shredding          | []     | []      | {}         | 10                 | 4                 | 4              | None         | []                    |
# | hammermill_body            | hammermillilng of car body                         | ELV  | material             | mechanical         | []     | []      | {}         | 5                  | 2                 | 1              | None         | []                    |
# | smelter_cc                 | smelting of catalytic converters                   | ELV  | element              | smelter            | []     | []      | {}         | 50                 | 20                | 10             | None         | []                    |
# | shredding_tyre             | shredding of tyres                                 | ELV  | material             | shredding          | []     | []      | {}         | 2                  | 6                 | 1.2            | None         | []                    |
# | shredding_elec             | shredding of electrical components                 | ELV  | material             | shredding          | []     | []      | {}         | 4                  | 3                 | 1.2            | None         | []                    |
# | shredding_batt             | shredding of a lead acid battery                   | ELV  | material             | shredding          | []     | []      | {}         | 6                  | 42                | 25.2           | None         | []                    |
# | smelter_nonferrous         | smelting of nonferrous fractions                   | ELV  | element              | smelter            | []     | []      | {}         | 45                 | 42                | 18.9           | None         | []                    |
# | smelter_ferrous            | smelting of ferrous fractions                      | ELV  | element              | smelter            | []     | []      | {}         | 60                 | 33                | 19.8           | None         | []                    |
# | market_waste_rubber        | market for waste rubber                            | None | market               | market             | []     | []      | {}         | None               | None              | -5             | None         | []                    |
# | market_ree                 | market for waste REE mix                           | None | market               | market             | []     | []      | {}         | None               | None              | -2000          | None         | []                    |
# | market_lead                | market for waste lead                              | None | market               | market             | []     | []      | {}         | None               | None              | -20            | None         | []                    |
# | market_H2SO4               | market for waste H2SO4                             | None | market               | market             | []     | []      | {}         | None               | None              | -10            | None         | []                    |
# | market_nonferrous          | market for waste non-ferrous                       | None | market               | market             | []     | []      | {}         | None               | None              | -5             | None         | []                    |
# | market_ferrous             | market for waste ferrous                           | None | market               | market             | []     | []      | {}         | None               | None              | -4             | None         | []                    |
# | market_waste               | market for waste (general)                         | None | market               | market             | []     | []      | {}         | None               | None              | 10             | None         | []                    |
# | market_waste_glass         | market for waste glass                             | None | market               | market             | []     | []      | {}         | None               | None              | -2             | None         | []                    |
# | market_waste_plastic       | market for waste plastic                           | None | market               | market             | []     | []      | {}         | None               | None              | -1             | None         | []                    |
# | market_waste_slag          | market for waste slag                              | None | market               | market             | []     | []      | {}         | None               | None              | -10            | None         | []                    |
# | market_waste_oil           | market for waste oil                               | None | market               | market             | []     | []      | {}         | None               | None              | 3              | None         | []                    |
# | PutOnMarket_ICE            | put on market for ICE vehicles                     | ELV  | input                | None               | []     | []      | {}         | None               | None              | None           | None         | []                    |
# +----------------------------+----------------------------------------------------+------+----------------------+--------------------+--------+---------+------------+--------------------+-------------------+----------------+--------------+-----------------------+

# %%
FLOWS_XLSX = DIR_DATA + "ELV_ICE_flows.xlsx"
f.utils.import_flows_xlsx(FLOWS_XLSX, model)

## TEST
if TEST:
    # FOR ONE PROCESS:
    print("\n\n A random process:")
    model.random_process().print_flows()
    # FOR THE WHOLE MODEL:
    print("\n\n All flows in the model:")
    model.print_flows()
# Out:
# ----------------------------------------------------------------------
# 	 Importing flows to model "TestModel_ELV" from ../data/ELV_ICE_flows.xlsx
# ----------------------------------------------------------------------
# Importing flow 1/31: collection_ICE -> dismantling_ICE
# Importing flow 2/31: PutOnMarket_ICE -> collection_ICE
# Importing flow 3/31: dismantling_ICE -> market_reuse_ELVcomponents
# Importing flow 4/31: dismantling_ICE -> shredding_batt
# Importing flow 5/31: dismantling_ICE -> hammermill_body
# Importing flow 6/31: dismantling_ICE -> smelter_cc
# Importing flow 7/31: dismantling_ICE -> shredding_elec
# Importing flow 8/31: dismantling_ICE -> shredding_engtrans
# Importing flow 9/31: dismantling_ICE -> market_waste_oil
# Importing flow 10/31: dismantling_ICE -> shredding_tyre
# Importing flow 11/31: dismantling_ICE -> market_reuse_ELVcomponents
# Importing flow 12/31: hammermill_body -> smelter_ferrous
# Importing flow 13/31: hammermill_body -> smelter_nonferrous
# Importing flow 14/31: hammermill_body -> market_waste
# Importing flow 15/31: shredding_batt -> market_waste_plastic
# Importing flow 16/31: shredding_batt -> market_H2SO4
# Importing flow 17/31: shredding_batt -> market_lead
# Importing flow 18/31: shredding_elec -> market_waste_plastic
# Importing flow 19/31: shredding_elec -> smelter_nonferrous
# Importing flow 20/31: shredding_engtrans -> market_waste_glass
# Importing flow 21/31: shredding_engtrans -> smelter_ferrous
# Importing flow 22/31: shredding_engtrans -> smelter_nonferrous
# Importing flow 23/31: shredding_engtrans -> market_waste
# Importing flow 24/31: shredding_tyre -> market_waste_rubber
# Importing flow 25/31: shredding_tyre -> smelter_ferrous
# Importing flow 26/31: smelter_cc -> market_waste_slag
# Importing flow 27/31: smelter_cc -> market_ree
# Importing flow 28/31: smelter_ferrous -> market_ferrous
# Importing flow 29/31: smelter_ferrous -> market_waste_slag
# Importing flow 30/31: smelter_nonferrous -> market_nonferrous
# Importing flow 31/31: smelter_nonferrous -> market_waste_slag
#
#
#  A random process:
#
# ------------------------------------------------------------
# 	  Flows of process: market_nonferrous
# ------------------------------------------------------------
# +-------+-----------------------------------------+--------------------+-------------------+-------------+--------+------+------+
# |  Type |                   Name                  |        From        |         To        | Composition | Amount | Unit | Tags |
# +-------+-----------------------------------------+--------------------+-------------------+-------------+--------+------+------+
# | Input | smelter_nonferrous_to_market_nonferrous | smelter_nonferrous | market_nonferrous | ELV_ICE_nfe |   0    |  kg  |  []  |
# +-------+-----------------------------------------+--------------------+-------------------+-------------+--------+------+------+
#
#
#  All flows in the model:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                    Flows in "TestModel_ELV"                                                                    |
# +-----------------------------------------------+--------+----------------------------+--------------------+--------+------+------------------------+------------+
# | Name                                          | Tags   | To                         | From               | Amount | Unit | Composition            | Parameters |
# +-----------------------------------------------+--------+----------------------------+--------------------+--------+------+------------------------+------------+
# | PutOnMarket_ICE_to_collection_ICE             | list 0 | collection_ICE             | PutOnMarket_ICE    | 0      | kg   | ELV_ICE                | dict 0     |
# | collection_ICE_to_dismantling_ICE             | list 0 | dismantling_ICE            | collection_ICE     | 0      | kg   | ELV_ICE                | dict 0     |
# | dismantling_ICE_to_market_reuse_ELVcomponents | list 0 | market_reuse_ELVcomponents | dismantling_ICE    | 0      | kg   | ELV_ICE_parts          | dict 0     |
# | dismantling_ICE_to_shredding_batt             | list 0 | shredding_batt             | dismantling_ICE    | 0      | kg   | ELV_ICE_batt           | dict 0     |
# | dismantling_ICE_to_hammermill_body            | list 0 | hammermill_body            | dismantling_ICE    | 0      | kg   | ELV_ICE_body           | dict 0     |
# | dismantling_ICE_to_smelter_cc                 | list 0 | smelter_cc                 | dismantling_ICE    | 0      | kg   | ELV_ICE_catconv        | dict 0     |
# | dismantling_ICE_to_shredding_elec             | list 0 | shredding_elec             | dismantling_ICE    | 0      | kg   | ELV_ICE_elec           | dict 0     |
# | dismantling_ICE_to_shredding_engtrans         | list 0 | shredding_engtrans         | dismantling_ICE    | 0      | kg   | ELV_ICE_engtrans       | dict 0     |
# | dismantling_ICE_to_market_waste_oil           | list 0 | market_waste_oil           | dismantling_ICE    | 0      | kg   | ELV_ICE_liquids        | dict 0     |
# | dismantling_ICE_to_shredding_tyre             | list 0 | shredding_tyre             | dismantling_ICE    | 0      | kg   | ELV_ICE_tyres          | dict 0     |
# | shredding_engtrans_to_market_waste_glass      | list 0 | market_waste_glass         | shredding_engtrans | 0      | kg   | ALL_glass              | dict 0     |
# | shredding_engtrans_to_smelter_ferrous         | list 0 | smelter_ferrous            | shredding_engtrans | 0      | kg   | ELV_ICE_fe             | dict 0     |
# | shredding_engtrans_to_smelter_nonferrous      | list 0 | smelter_nonferrous         | shredding_engtrans | 0      | kg   | ELV_ICE_nfe            | dict 0     |
# | shredding_engtrans_to_market_waste            | list 0 | market_waste               | shredding_engtrans | 0      | kg   | ELV_ICE_waste_shredder | dict 0     |
# | hammermill_body_to_smelter_ferrous            | list 0 | smelter_ferrous            | hammermill_body    | 0      | kg   | ELV_ICE_fe             | dict 0     |
# | hammermill_body_to_smelter_nonferrous         | list 0 | smelter_nonferrous         | hammermill_body    | 0      | kg   | ELV_ICE_nfe            | dict 0     |
# | hammermill_body_to_market_waste               | list 0 | market_waste               | hammermill_body    | 0      | kg   | ELV_ICE_waste_shredder | dict 0     |
# | smelter_cc_to_market_waste_slag               | list 0 | market_waste_slag          | smelter_cc         | 0      | kg   | ALL_slag_ree           | dict 0     |
# | smelter_cc_to_market_ree                      | list 0 | market_ree                 | smelter_cc         | 0      | kg   | ELV_ICE_ree            | dict 0     |
# | shredding_tyre_to_market_waste_rubber         | list 0 | market_waste_rubber        | shredding_tyre     | 0      | kg   | ALL_rubber             | dict 0     |
# | shredding_tyre_to_smelter_ferrous             | list 0 | smelter_ferrous            | shredding_tyre     | 0      | kg   | ELV_ICE_fe             | dict 0     |
# | shredding_elec_to_market_waste_plastic        | list 0 | market_waste_plastic       | shredding_elec     | 0      | kg   | ALL_plastic            | dict 0     |
# | shredding_elec_to_smelter_nonferrous          | list 0 | smelter_nonferrous         | shredding_elec     | 0      | kg   | ELV_ICE_nfe            | dict 0     |
# | shredding_batt_to_market_waste_plastic        | list 0 | market_waste_plastic       | shredding_batt     | 0      | kg   | ALL_plastic            | dict 0     |
# | shredding_batt_to_market_H2SO4                | list 0 | market_H2SO4               | shredding_batt     | 0      | kg   | H2SO4                  | dict 0     |
# | shredding_batt_to_market_lead                 | list 0 | market_lead                | shredding_batt     | 0      | kg   | Pb                     | dict 0     |
# | smelter_nonferrous_to_market_nonferrous       | list 0 | market_nonferrous          | smelter_nonferrous | 0      | kg   | ELV_ICE_nfe            | dict 0     |
# | smelter_nonferrous_to_market_waste_slag       | list 0 | market_waste_slag          | smelter_nonferrous | 0      | kg   | ELV_ICE_slag_nfe       | dict 0     |
# | smelter_ferrous_to_market_ferrous             | list 0 | market_ferrous             | smelter_ferrous    | 0      | kg   | ELV_ICE_fe             | dict 0     |
# | smelter_ferrous_to_market_waste_slag          | list 0 | market_waste_slag          | smelter_ferrous    | 0      | kg   | ELV_ICE_slag_fe        | dict 0     |
# +-----------------------------------------------+--------+----------------------------+--------------------+--------+------+------------------------+------------+

# %%
TRANSFER_COEFFICIENTS_XLSX = DIR_DATA + "ELV_ICE_TCs.xlsx"
f.utils.import_transfercoefficients_xlsx(TRANSFER_COEFFICIENTS_XLSX, model)

## TEST:
if TEST:
    # FOR ONE PROCESS
    print("\n\n A random process:")
    model.random_process().print_transfer_coefficients()
    # FOR THE WHOLE MODEL
    print("\n\n All transfer coefficients in the model:")
    model.print_transfer_coefficients()
# Out:
# ******************************************************************************************
#   Importing transfer coefficients to model "TestModel_ELV" from ../data/ELV_ICE_TCs.xlsx
# ******************************************************************************************
# 	* shredding_engtrans 		(ELV_ICE_body --0.57--> ALL_glass)
# 	* shredding_elec 		(ELV_ICE_elec --0.98--> ALL_plastic)
# 	* shredding_batt 		(ELV_ICE_batt --0.31--> ALL_plastic)
# 	* shredding_tyre 		(ELV_ICE_tyres --0.92--> ALL_rubber)
# 	* dismantling_ICE 		(ELV_ICE --0.65--> ELV_ICE_parts)
# 	* collection_ICE 		(ELV_ICE --0.21--> ELV_ICE)
# 	* dismantling_ICE 		(ELV_ICE --0.62--> ELV_ICE)
# 	* dismantling_ICE 		(ELV_ICE --0.98--> ELV_ICE_batt)
# 	* dismantling_ICE 		(ELV_ICE --0.65--> ELV_ICE_body)
# 	* dismantling_ICE 		(ELV_ICE --0.7--> ELV_ICE_catconv)
# 	* dismantling_ICE 		(ELV_ICE --0.13--> ELV_ICE_elec)
# 	* dismantling_ICE 		(ELV_ICE --0.62--> ELV_ICE_engtrans)
# 	* shredding_engtrans 		(ELV_ICE_body --0.25--> ELV_ICE_fe)
# 	* hammermill_body 		(ELV_ICE_engtrans --0.43--> ELV_ICE_fe)
# 	* smelter_cc 		(ELV_ICE_catconv --0.99--> ELV_ICE_fe)
# 	* shredding_tyre 		(ELV_ICE_tyres --0.56--> ELV_ICE_fe)
# 	* smelter_ferrous 		(ELV_ICE_fe --0.07--> ELV_ICE_fe)
# 	* dismantling_ICE 		(ELV_ICE --0.59--> ELV_ICE_liquids)
# 	* shredding_engtrans 		(ELV_ICE_body --0.18--> ELV_ICE_nfe)
# 	* hammermill_body 		(ELV_ICE_engtrans --0.27--> ELV_ICE_nfe)
# 	* shredding_elec 		(ELV_ICE_elec --0.9--> ELV_ICE_nfe)
# 	* smelter_nonferrous 		(ELV_ICE_nfe --0.22--> ELV_ICE_nfe)
# 	* smelter_cc 		(ELV_ICE_catconv --0.74--> ELV_ICE_ree)
# 	* smelter_ferrous 		(ELV_ICE_fe --0.52--> ELV_ICE_slag_fe)
# 	* smelter_nonferrous 		(ELV_ICE_nfe --0.23--> ELV_ICE_slag_nfe)
# 	* dismantling_ICE 		(ELV_ICE --0.24--> ELV_ICE_tyres)
# 	* shredding_engtrans 		(ELV_ICE_body --0.67--> ELV_ICE_waste_shredder)
# 	* hammermill_body 		(ELV_ICE_engtrans --0.02--> ELV_ICE_waste_shredder)
# 	* smelter_cc 		(ELV_ICE_catconv --0.54--> ALL_slag_ree)
# 	* shredding_batt 		(ELV_ICE_batt --0.2--> H2SO4)
# 	* shredding_batt 		(ELV_ICE_batt --0.6--> Pb)
# 	* PutOnMarket_ICE 		(NEW_ICE --0.8--> ELV_ICE)
#
#
#  A random process:
# market_waste_oil: Market processes don't have transfer coefficients.
#
#
#  All transfer coefficients in the model:
# +--------------------------------------------------------------------------------+
# |    There are 32             transfer coefficients in model "TestModel_ELV"     |
# +------------------------+------------------+----------------------+-------------+
# |  Input                 | Output           | Transfer coefficient | Uncertainty |
# +------------------------+------------------+----------------------+-------------+
# | ELV_ICE                | ELV_ICE          | 0.21                 | 0.1         |
# | ELV_ICE_parts          | ELV_ICE          | 0.65                 | 0.1         |
# | ELV_ICE                | ELV_ICE          | 0.62                 | 0.1         |
# | ELV_ICE_batt           | ELV_ICE          | 0.98                 | 0.1         |
# | ELV_ICE_body           | ELV_ICE          | 0.65                 | 0.1         |
# | ELV_ICE_catconv        | ELV_ICE          | 0.70                 | 0.1         |
# | ELV_ICE_elec           | ELV_ICE          | 0.13                 | 0.1         |
# | ELV_ICE_engtrans       | ELV_ICE          | 0.62                 | 0.1         |
# | ELV_ICE_liquids        | ELV_ICE          | 0.59                 | 0.1         |
# | ELV_ICE_tyres          | ELV_ICE          | 0.24                 | 0.1         |
# | ALL_glass              | ELV_ICE_body     | 0.57                 | 0.1         |
# | ELV_ICE_fe             | ELV_ICE_body     | 0.25                 | 0.1         |
# | ELV_ICE_nfe            | ELV_ICE_body     | 0.18                 | 0.1         |
# | ELV_ICE_waste_shredder | ELV_ICE_body     | 0.67                 | 0.1         |
# | ELV_ICE_fe             | ELV_ICE_engtrans | 0.43                 | 0.1         |
# | ELV_ICE_nfe            | ELV_ICE_engtrans | 0.27                 | 0.1         |
# | ELV_ICE_waste_shredder | ELV_ICE_engtrans | 0.02                 | 0.1         |
# | ELV_ICE_fe             | ELV_ICE_catconv  | 0.99                 | 0.1         |
# | ELV_ICE_ree            | ELV_ICE_catconv  | 0.74                 | 0.1         |
# | ALL_slag_ree           | ELV_ICE_catconv  | 0.54                 | 0.1         |
# | ALL_rubber             | ELV_ICE_tyres    | 0.92                 | 0.1         |
# | ELV_ICE_fe             | ELV_ICE_tyres    | 0.56                 | 0.1         |
# | ALL_plastic            | ELV_ICE_elec     | 0.98                 | 0.1         |
# | ELV_ICE_nfe            | ELV_ICE_elec     | 0.90                 | 0.1         |
# | ALL_plastic            | ELV_ICE_batt     | 0.31                 | 0.1         |
# | H2SO4                  | ELV_ICE_batt     | 0.20                 | 0.1         |
# | Pb                     | ELV_ICE_batt     | 0.60                 | 0.1         |
# | ELV_ICE_nfe            | ELV_ICE_nfe      | 0.22                 | 0.1         |
# | ELV_ICE_slag_nfe       | ELV_ICE_nfe      | 0.23                 | 0.1         |
# | ELV_ICE_fe             | ELV_ICE_fe       | 0.07                 | 0.1         |
# | ELV_ICE_slag_fe        | ELV_ICE_fe       | 0.52                 | 0.1         |
# | ELV_ICE                | NEW_ICE          | 0.80                 | 0.1         |
# +------------------------+------------------+----------------------+-------------+

# %%
f.utils.validate_model(model)
# Out:
# ==========================================================================================
# 	 Validating model: "TestModel_ELV"
# ==========================================================================================
#
# ------------------------------------------------------------
# 	 Validating flows in model: "TestModel_ELV"
# ------------------------------------------------------------
#
# 	** Model flows validated **
#  All processes referred to in flows are in the model: "TestModel_ELV"
#
# ------------------------------------------------------------
# 	 Validating matter in model: "TestModel_ELV"
# ------------------------------------------------------------
#
# 	** Model matter validated! **
#  All matter referred to in flows are in the model: "TestModel_ELV"
#
#
# ============================================================
# 	** Model validated! **
# ------------------------------------------------------------------------------------------
#  All processes and matter referred to in the model are in the model: "TestModel_ELV"
# ============================================================
# True

# %%
# This would come from a csv in the final version
waste_input = model.flows['PutOnMarket_ICE_to_collection_ICE']
waste_input.amount = 10^6

# %%
model.calculate_flows()

# %%
## INDIVIDUAL PROCESSES
# Create isolated flowcharts for each process in the model,
# showing only the process and its direct inputs and outputs

model.make_flowchart_processes()

# % WHOLE MODEL

# Create a flowchart for the whole model, showing
# all processes and their inputs and outputs

model.make_flowchart_model()
model.make_network()
# Out:
# ================================================================================
#  Making isolated flow charts for the23 processes in model 'TestModel_ELV'
# ================================================================================
#
# 1/23.
# 	Process flowchart created for: collection_ICE
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/collection_ICE.pdf
# 2/23.
# 	Process flowchart created for: dismantling_ICE
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/dismantling_ICE.pdf
# 3/23.
# 	Process flowchart created for: market_reuse_ELVcomponents
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_reuse_ELVcomponents.pdf
# 4/23.
# 	Process flowchart created for: shredding_engtrans
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/shredding_engtrans.pdf
# 5/23.
# 	Process flowchart created for: hammermill_body
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/hammermill_body.pdf
# 6/23.
# 	Process flowchart created for: smelter_cc
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/smelter_cc.pdf
# 7/23.
# 	Process flowchart created for: shredding_tyre
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/shredding_tyre.pdf
# 8/23.
# 	Process flowchart created for: shredding_elec
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/shredding_elec.pdf
# 9/23.
# 	Process flowchart created for: shredding_batt
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/shredding_batt.pdf
# 10/23.
# 	Process flowchart created for: smelter_nonferrous
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/smelter_nonferrous.pdf
# 11/23.
# 	Process flowchart created for: smelter_ferrous
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/smelter_ferrous.pdf
# 12/23.
# 	Process flowchart created for: market_waste_rubber
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste_rubber.pdf
# 13/23.
# 	Process flowchart created for: market_ree
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_ree.pdf
# 14/23.
# 	Process flowchart created for: market_lead
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_lead.pdf
# 15/23.
# 	Process flowchart created for: market_H2SO4
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_H2SO4.pdf
# 16/23.
# 	Process flowchart created for: market_nonferrous
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_nonferrous.pdf
# 17/23.
# 	Process flowchart created for: market_ferrous
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_ferrous.pdf
# 18/23.
# 	Process flowchart created for: market_waste
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste.pdf
# 19/23.
# 	Process flowchart created for: market_waste_glass
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste_glass.pdf
# 20/23.
# 	Process flowchart created for: market_waste_plastic
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste_plastic.pdf
# 21/23.
# 	Process flowchart created for: market_waste_slag
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste_slag.pdf
# 22/23.
# 	Process flowchart created for: market_waste_oil
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/market_waste_oil.pdf
# 23/23.
# 	Process flowchart created for: PutOnMarket_ICE
# 		 View .pdf @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/processes/pdf/PutOnMarket_ICE.pdf
# ================================================================================
#  Created 23 isolated process flowcharts
#  ================================================================================
#
#
#
# ==========================================================================================
# 	 Creating flowchart for model: TestModel_ELV
# ==========================================================================================
# 	 Model flowchart created in figures folder for TestModel_ELV
# 	View @ /home/stew/code/gh/futuram/IntegratedModel/src/examples/ELV/figures/flowcharts/models/pdf/TestModel_ELV.pdf
#
#
#
# ==========================================================================================
# 	 Making process network for model: TestModel_ELV
# ==========================================================================================
#
# Process network figure saved to ../figures/TestModel_ELV_process_network.pdf

# %%
# Create flowcharts for the whole model based on filters
# (eg: [WS=='ELV'], or ['market' in process.tags] etc.)

# TODO: still need to implement this, just an adaption of the above flowchart function

# %%
# Create flowcharts for the whole model based on matter
# (eg: [matter.name=='steel'], or ['iron' in matter.tags] etc.)

# TODO: still need to write this

# %%
print(f"\n\n{'='*60}\n\t {'FIN '*10} \n{'='*60}\n")
# Out:
# ============================================================
# 	 FIN FIN FIN FIN FIN FIN FIN FIN FIN FIN
# ============================================================
